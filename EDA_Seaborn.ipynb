# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("titanic_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
plt.boxplot(df["Age"]);

# %%
plt.boxplot(df["Age"].dropna());

# %%
dftemp=df[["Age","Sex"]]
dftemp=dftemp.dropna()
dfM=dftemp[dftemp["Sex"]=="male"]
dfF=dftemp[dftemp["Sex"]=="female"]

# %%
plt.boxplot([dfM["Age"],dfF["Age"]]);

# %%
import seaborn as sns

# %%
sns.boxplot(data=df,x="Sex",y="Age");

# %%
sns.boxplot(data=df,x="Pclass",y="Age");

# %%
sns.boxplot(data=df,x="Pclass",y="Fare");

# %%
sns.boxplot(data=df,x="Fare",y="Pclass");

# %%
df["Pclass"]=df["Pclass"].apply(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
sns.boxplot(data=df,x="Fare",y="Pclass");

# %%
sns.boxplot(data=df,x="Fare",y="Pclass",order=["1","2","3"]);

# %%
df["Survived"]=df["Survived"].apply(str)

# %%
sns.boxplot(data=df,x="Fare",y="Survived",order=["1","0"]);

# %%
sns.boxplot(data=df,y="Age",x="Survived",order=["1","0"]);

# %%
sns.boxplot(data=df,y="Age",x="Survived",hue="Sex",order=["1","0"]);

# %%
sns.boxplot(data=df,y="Age",x="Pclass",hue="Sex",order=["1","2","3"]);

# %%
df2=df.sort_values(["Pclass","Survived"])
sns.boxplot(data=df2,y="Age",x="Pclass",hue="Sex",palette=["peachpuff","darkseagreen"]);

# %%
sns.violinplot(data=df2,y="Age",x="Pclass",hue="Sex",palette=["peachpuff","darkseagreen"]);

# %%
sns.violinplot(data=df2,y="Age",x="Pclass",hue="Sex",palette=["peachpuff","darkseagreen"]
              ,inner="quartile");

# %%
plt.hist(df["Age"],edgecolor="white");

# %%
plt.hist(df["Age"],edgecolor="white",bins=20);

# %%
plt.hist(df["Age"],edgecolor="white",bins=20);
plt.xlabel("Age")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.mlab as mlab

# %%
from scipy.stats import norm

# %%
mu,sigma=norm.fit(df["Age"].dropna())

# %%
plt.hist(df["Age"],edgecolor="white",bins=20,density=True);
ages=np.linspace(0,80,100)
plt.plot(ages,norm.pdf(ages,mu,sigma),linewidth=4)
plt.show()

# %%
dfnum=df[["Age","Fare"]]
dfnum=dfnum.dropna()

plt.scatter(x=dfnum["Age"],y=dfnum["Fare"]);

# %%
plt.scatter(x=dfnum["Age"],y=dfnum["Fare"],marker='+',alpha=0.5);

# %%
plt.scatter(x=dfnum["Age"],y=np.log10(dfnum["Fare"]),alpha=0.5);
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
dfnum=df[["Age","Fare","Survived","Pclass"]]
dfnum=dfnum.dropna()


plt.scatter(x=dfnum["Age"],y=np.log10(dfnum["Fare"])
            ,c=pd.to_numeric(dfnum["Survived"]), alpha=0.5);
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
dfnum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 890
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       714 non-null    float64
#  1   Fare      714 non-null    float64
#  2   Survived  714 non-null    object
#  3   Pclass    714 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 27.9+ KB

# %%
dfnum=df[["Age","Fare","Survived","Pclass"]]
dfnum=dfnum.dropna()


plt.scatter(x=dfnum["Age"],y=np.log10(dfnum["Fare"])
            ,c=pd.to_numeric(dfnum["Survived"])
            ,s=pd.to_numeric(dfnum["Pclass"])*100
            , alpha=0.2);
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
p=sns.scatterplot(data=df,x="Age",y="Fare",hue="Survived",alpha=.6)
p.set_yscale("log")
plt.ylim(5,500);

# %%
p=sns.scatterplot(data=df,x="Age",y="Fare",hue="Survived",alpha=.6)
p.set_yscale("log")
plt.ylim(5,500);


plt.savefig("test_fig_1.pdf")

# %%
sns.set_theme()

p=sns.scatterplot(data=df,x="Age",y="Fare",hue="Survived",alpha=.6)
p.set_yscale("log")
plt.ylim(5,500);

# %%
sns.set_style("whitegrid")

p=sns.scatterplot(data=df,x="Age",y="Fare",hue="Survived",alpha=.6)
p.set_yscale("log")
plt.ylim(5,500);

# %%
sns.set_style("dark")

p=sns.scatterplot(data=df,x="Age",y="Fare",hue="Survived",alpha=.6)
p.set_yscale("log")
plt.ylim(5,500);

# %%
sns.set_style("white")

p=sns.scatterplot(data=df,x="Age",y="Fare",hue="Survived",alpha=.6)
p.set_yscale("log")
plt.ylim(5,500);

# %%
sns.set_style("ticks")

p=sns.scatterplot(data=df,x="Age",y="Fare",hue="Survived",alpha=.6)
p.set_yscale("log")
plt.ylim(5,500);

# %%
sns.set_style("ticks")

p=sns.scatterplot(data=df,x="Age",y="Fare",hue="Survived",alpha=.6)
p.set_yscale("log")
plt.ylim(5,500);
sns.despine()

# %%
sns.set_style("ticks")

p=sns.scatterplot(data=df,x="Age",y="Fare",hue="Survived",alpha=.6)
p.set_yscale("log")
plt.ylim(5,500);
sns.despine(left=True)

# %%
sns.set_theme()

p=sns.scatterplot(data=df,x="Age",y="Fare",hue="Survived",alpha=.6)
p.set_yscale("log")
plt.ylim(5,500);

plt.savefig("test_fig_2.pdf")

# %%
sns.set_theme()


sns.set_context("poster")


p=sns.scatterplot(data=df,x="Age",y="Fare",hue="Survived",alpha=.6)
p.set_yscale("log")
plt.ylim(5,500);

# %%
sns.plotting_context()
# Out:
# {'font.size': 24.0,
#  'axes.labelsize': 24.0,
#  'axes.titlesize': 24.0,
#  'xtick.labelsize': 22.0,
#  'ytick.labelsize': 22.0,
#  'legend.fontsize': 22.0,
#  'axes.linewidth': 2.5,
#  'grid.linewidth': 2.0,
#  'lines.linewidth': 3.0,
#  'lines.markersize': 12.0,
#  'patch.linewidth': 2.0,
#  'xtick.major.width': 2.5,
#  'ytick.major.width': 2.5,
#  'xtick.minor.width': 2.0,
#  'ytick.minor.width': 2.0,
#  'xtick.major.size': 12.0,
#  'ytick.major.size': 12.0,
#  'xtick.minor.size': 8.0,
#  'ytick.minor.size': 8.0,
#  'legend.title_fontsize': 24.0}

# %%
sns.set_theme()


sns.set_context("poster",font_scale=.5
                ,rc={"grid.linewidth":2,"xtick.labelsize":15,"ytick.labelsize":15})

p=sns.scatterplot(data=df,x="Age",y="Fare",hue="Survived",alpha=.6)
p.set_yscale("log")
plt.ylim(5,500);

# %%
sns.set_theme()


sns.set_context("poster",font_scale=.5
                ,rc={"grid.linewidth":2,"xtick.labelsize":15,"ytick.labelsize":15})

p=sns.scatterplot(data=df,x="Age",y="Fare",hue="Survived",style="Sex",alpha=.6)
p.set_yscale("log")
plt.ylim(5,500);

# %%
sns.scatterplot(data=df,x="Age",y="Fare",hue="Survived",style="Sex",alpha=.6)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.relplot(data=df,x="Age",y="Fare",kind="line",ci="sd")

# %%
sns.relplot(data=df,x="Age",y="Fare",hue="Survived",kind="line",ci="sd")

# %%
sns.relplot(data=df,x="Age",y="Fare",hue="Survived",kind="line",ci="sd",aspect=2)

# %%
sns.relplot(data=df,x="Age",y="Fare",hue="Survived",style="Sex",kind="line",ci="sd",aspect=2)

# %%
sns.relplot(data=df,x="Age",y="Fare",hue="Survived",style="Sex",kind="line",ci=None,aspect=2)

# %%
sns.displot(data=df,x="Age");

# %%
sns.displot(data=df,x="Survived");

# %%
sns.displot(data=df,x="Survived",hue="Pclass");

# %%
sns.displot(data=df,x="Survived",hue="Pclass",multiple="stack");

# %%
sns.displot(data=df,x="Survived",hue="Pclass",multiple="stack",stat="density");

# %%
df2=df.sort_values("Pclass")
sns.displot(data=df2,x="Survived",hue="Pclass",multiple="stack",stat="density");

# %%
df2=df.sort_values(["Pclass","Survived"])
sns.displot(data=df2,x="Survived",hue="Pclass",multiple="dodge",stat="density");

# %%
df2=df.sort_values(["Pclass","Survived"])
sns.displot(data=df2,x="Pclass",hue="Survived",multiple="stack",stat="density");

# %%
df2=df.sort_values(["Pclass","Survived"])
sns.displot(data=df2,x="Pclass",hue="Survived",multiple="dodge",stat="density");

# %%
df2=df.sort_values(["Pclass","Survived"])
sns.displot(data=df2,x="Survived",hue="Sex",multiple="stack",stat="density");

# %%
df2=df.sort_values(["Pclass","Survived"])
sns.displot(data=df2,x="Sex",hue="Survived",multiple="stack",stat="density");

# %%
sns.displot(data=df,x="Age",hue="Survived",multiple="stack",stat="density")

# %%
sns.displot(data=df,x="Age",hue="Sex",multiple="stack",stat="density")

# %%
sns.displot(data=df,x="Age",kind="kde");

# %%
sns.displot(data=df2,x="Age",hue="Pclass",kind="kde",multiple="stack");

# %%
sns.displot(data=df2,x="Age",kind="ecdf" );

# %%
sns.displot(data=df2,x="Age",hue="Pclass",kind="ecdf" );

# %%
df4=df
df4=df4[df4["Age"]!=0]
df4=df4[df4["Fare"]!=0]

sns.displot(data=df4,x="Age",y="Fare",log_scale=[False,True]);

# %%
bm=pd.read_csv("marathon_results_2017.csv")

# %%
bm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26410 entries, 0 to 26409
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           26410 non-null  object
#  1   Age            26410 non-null  int64
#  2   M/F            26410 non-null  object
#  3   City           26410 non-null  object
#  4   State          22815 non-null  object
#  5   Country        26410 non-null  object
#  6   5K             26410 non-null  int64
#  7   10K            26410 non-null  int64
#  8   15K            26410 non-null  int64
#  9   20K            26410 non-null  int64
#  10  Half           26410 non-null  int64
#  11  25K            26410 non-null  int64
#  12  30K            26410 non-null  int64
#  13  35K            26410 non-null  int64
#  14  40K            26410 non-null  int64
#  15  Official Time  26410 non-null  int64
#  16  speed (km/h)   26410 non-null  float64
#  17  speed (mph)    26410 non-null  float64
# dtypes: float64(2), int64(11), object(5)
# memory usage: 3.6+ MB

# %%
sns.displot(data=bm,x="Age",y="speed (km/h)")

# %%
sns.jointplot(data=bm,x="Age",y="speed (km/h)",s=10);

# %%
sns.jointplot(data=bm,x="Age",y="speed (km/h)",kind="hist");

# %%
sns.jointplot(data=bm,x="Age",y="speed (km/h)",kind="hex");

# %%
sns.jointplot(data=bm,x="Age",y="speed (km/h)",kind="reg",line_kws={"color":"red"});

# %%
sns.jointplot(data=bm,x="Age",y="speed (km/h)",kind="kde");

# %%
sns.jointplot(data=bm,x="Age",y="speed (km/h)",hue="M/F",kind="kde");

# %%
sns.relplot(data=bm,x="Age",y="speed (km/h)",kind="line",ci="sd",aspect=1.5)

# %%
sns.relplot(data=bm,x="Age",y="speed (km/h)",hue="M/F",kind="line",ci="sd",aspect=1.5)

# %%
iris=pd.read_csv("iris.csv")
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue="species")
